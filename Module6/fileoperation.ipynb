# %%
import csv
with open(r"D:\GenAI2026\sample1.txt", mode='r', newline='') as file:
    content=file.read()
    print(content)
# Out:
# Hi , I am sampat bansode, how are you?
# I am going to learn new LLM course using langchain
# I have nothing knowlegde on Pyhton.
# But daring to learn LLM , thats the joke right?

# %%
## Read file line by line
with open(r"D:\GenAI2026\sample1.txt", mode='r') as file:
    count = 0
    for line in file:
        print(line.strip())
        count += 1
    print(count)
# Out:
# Hi , I am sampat bansode, how are you?
# I am going to learn new LLM course using langchain
# I have nothing knowlegde on Pyhton.
# But daring to learn LLM , thats the joke right?
# 4

# %%
### write file override

with open("sample1.txt",mode='w') as file:
    file.write("all lines should be overridden\n")

# %%
## writing file withous override

with open("sample1.txt",mode='a') as file:
    file.write("writing without override\n")

# %%
##writing the list of lines

lines=["this is first line\n", "Second line\n", "Third line\n","forth Line\n"]

with open("sample1.txt", mode='w') as file:
    file.writelines(lines)

# %%
## Write the binary files

data=b'\x00\x01\x02\x03\x04'

with open("binary.bin", mode='wb') as file:
    file.write(data)

# %%
## Read content from source file and write this into desttination file

with open("sample1.txt", mode='r') as file:
    content=file.read()
    print(content)

with open("destination.txt", mode='w') as file:
    file.write(content)
# Out:
# this is first line
# Second line
# Third line
# forth Line

# %%
## read the file and count the number of lines , words and characters

def read_file_content(file_path):
    with open(file_path, mode='r') as file:
        lines=file.readlines()
        lines_count=len(lines)
        word_count=sum(len(line.split())for line in lines)
        char_count= sum(len(line) for line in lines)
        return lines_count, word_count, char_count

read_file_content("sample1.txt")
# Out:
# (5, 19, 101)
