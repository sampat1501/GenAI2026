# %%
## it is Fucntion without name , anonymouse function, and have only 1 expression, commanly used for short operations

from operator import add


addtion=lambda a, b:a+b

print(addtion(7,9))
# Out:
# 16

# %%
square=lambda x:x**2

print(square(81))
# Out:
# 6561

# %%
##Check even numbers

even_num=lambda s:s%2==0
print(even_num(22))
# Out:
# True
